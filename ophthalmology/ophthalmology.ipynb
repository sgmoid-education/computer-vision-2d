# %% [markdown]
# **Overview**
# A simple tutorial to classify skin lesions based on the image
#
# **Original Data Source**
#
# **Original Challenge:** https://challenge2018.isic-archive.com https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/DBW86T
# [1] Noel Codella, Veronica Rotemberg, Philipp Tschandl, M. Emre Celebi, Stephen Dusza, David Gutman, Brian Helba, Aadi Kalloo, Konstantinos Liopyris, Michael Marchetti, Harald Kittler, Allan Halpern: “Skin Lesion Analysis Toward Melanoma Detection 2018: A Challenge Hosted by the International Skin Imaging Collaboration (ISIC)”, 2018; https://arxiv.org/abs/1902.03368
#
# [2] Tschandl, P., Rosendahl, C. & Kittler, H. The HAM10000 dataset, a large collection of multi-source dermatoscopic images of common pigmented skin lesions. Sci. Data 5, 180161 doi:10.1038/sdata.2018.161 (2018).
#
# **From Authors** Training of neural networks for automated diagnosis of pigmented skin lesions is hampered by the small size and lack of diversity of available dataset of dermatoscopic images. We tackle this problem by releasing the HAM10000 ("Human Against Machine with 10000 training images") dataset.
#
# We collected dermatoscopic images from different populations, acquired and stored by different modalities. The final dataset consists of 10015 dermatoscopic images which can serve as a training set for academic machine learning purposes. Cases include a representative collection of all important diagnostic categories in the realm of pigmented lesions: Actinic keratoses and intraepithelial carcinoma / Bowen's disease (akiec), basal cell carcinoma (bcc), benign keratosis-like lesions (solar lentigines / seborrheic keratoses and lichen-planus like keratoses, bkl), dermatofibroma (df), melanoma (mel), melanocytic nevi (nv) and vascular lesions (angiomas, angiokeratomas, pyogenic granulomas and hemorrhage, vasc).
# More than 50% of lesions are confirmed through histopathology (histo), the ground truth for the rest of the cases is either follow-up examination (followup), expert consensus (consensus), or confirmation by in-vivo confocal microscopy (confocal). The dataset includes lesions with multiple images, which can be tracked by the lesionid-column within the HAM10000_metadata file. The test set is not public, but the evaluation server remains running (see the challenge website). Any publications written using the HAM10000 data should be evaluated on the official test set hosted there, so that methods can be fairly compared.

# %% [markdown]
# # Mount Google Drive

# %% [markdown]
# Mount the Google Drive. Basic step to make sure your Google Colab and your Google Drive is connected. Useful for accessing files & folders from your drive. By default Google provides you 20GB space. I think it is $2/month for an additional 100 GB storage

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0

# %% [markdown]
# Installing pytorch

# %%
# !pip install torch==1.7.1+cu110 torchvision==0.8.2+cu110 torchaudio==0.7.2 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch==1.7.1+cu110
#   Downloading https://download.pytorch.org/whl/cu110/torch-1.7.1%2Bcu110-cp37-cp37m-linux_x86_64.whl (1156.8MB)
#      |███████████████████████         | 834.1MB 1.3MB/s eta 0:04:07tcmalloc: large alloc 1147494400 bytes == 0x55cea8f66000 @  0x7ff378b06615 0x55ce6ff2606c 0x55ce70005eba 0x55ce6ff28e8d 0x55ce7001a99d 0x55ce6ff9cfe9 0x55ce6ff97b0e 0x55ce6ff2a77a 0x55ce6ff9ce50 0x55ce6ff97b0e 0x55ce6ff2a77a 0x55ce6ff9986a 0x55ce7001b7c6 0x55ce6ff98ee2 0x55ce7001b7c6 0x55ce6ff98ee2 0x55ce7001b7c6 0x55ce6ff98ee2 0x55ce7001b7c6 0x55ce7009d431 0x55ce6fffe049 0x55ce6ff68c84 0x55ce6ff298e9 0x55ce6ff9dade 0x55ce6ff2a69a 0x55ce6ff98a45 0x55ce6ff97e0d 0x55ce6ff2a77a 0x55ce6ff98a45 0x55ce6ff2a69a 0x55ce6ff98a45
#      |█████████████████████████████▏  | 1055.7MB 1.2MB/s eta 0:01:22tcmalloc: large alloc 1434370048 bytes == 0x55ceed5bc000 @  0x7ff378b06615 0x55ce6ff2606c 0x55ce70005eba 0x55ce6ff28e8d 0x55ce7001a99d 0x55ce6ff9cfe9 0x55ce6ff97b0e 0x55ce6ff2a77a 0x55ce6ff9ce50 0x55ce6ff97b0e 0x55ce6ff2a77a 0x55ce6ff9986a 0x55ce7001b7c6 0x55ce6ff98ee2 0x55ce7001b7c6 0x55ce6ff98ee2 0x55ce7001b7c6 0x55ce6ff98ee2 0x55ce7001b7c6 0x55ce7009d431 0x55ce6fffe049 0x55ce6ff68c84 0x55ce6ff298e9 0x55ce6ff9dade 0x55ce6ff2a69a 0x55ce6ff98a45 0x55ce6ff97e0d 0x55ce6ff2a77a 0x55ce6ff98a45 0x55ce6ff2a69a 0x55ce6ff98a45
#      |████████████████████████████████| 1156.7MB 1.2MB/s eta 0:00:01tcmalloc: large alloc 1445945344 bytes == 0x55cf42da8000 @  0x7ff378b06615 0x55ce6ff2606c 0x55ce70005eba 0x55ce6ff28e8d 0x55ce7001a99d 0x55ce6ff9cfe9 0x55ce6ff97b0e 0x55ce6ff2a77a 0x55ce6ff98c9e 0x55ce6ff97b0e 0x55ce6ff2a77a 0x55ce6ff98c9e 0x55ce6ff97b0e 0x55ce6ff2a77a 0x55ce6ff98c9e 0x55ce6ff97b0e 0x55ce6ff2a77a 0x55ce6ff98c9e 0x55ce6ff97b0e 0x55ce6ff2a77a 0x55ce6ff98c9e 0x55ce6ff2a69a 0x55ce6ff98c9e 0x55ce6ff97b0e 0x55ce6ff2a77a 0x55ce6ff9986a 0x55ce6ff97b0e 0x55ce6ff2a77a 0x55ce6ff9986a 0x55ce6ff97b0e 0x55ce6ff2ae11
#      |████████████████████████████████| 1156.8MB 16kB/s
# Collecting torchvision==0.8.2+cu110
#   Downloading https://download.pytorch.org/whl/cu110/torchvision-0.8.2%2Bcu110-cp37-cp37m-linux_x86_64.whl (12.9MB)
#      |████████████████████████████████| 12.9MB 241kB/s
# Collecting torchaudio==0.7.2
#   Downloading https://files.pythonhosted.org/packages/37/16/ecdb9eb09ec6b8133d6c9536ea9e49cd13c9b5873c8488b8b765a39028da/torchaudio-0.7.2-cp37-cp37m-manylinux1_x86_64.whl (7.6MB)
#      |████████████████████████████████| 7.6MB 13.6MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.7.1+cu110) (3.7.4.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch==1.7.1+cu110) (1.19.5)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.8.2+cu110) (7.0.0)
# ERROR: torchtext 0.9.0 has requirement torch==1.8.0, but you'll have torch 1.7.1+cu110 which is incompatible.
# Installing collected packages: torch, torchvision, torchaudio
#   Found existing installation: torch 1.8.0+cu101
#     Uninstalling torch-1.8.0+cu101:
#       Successfully uninstalled torch-1.8.0+cu101
#   Found existing installation: torchvision 0.9.0+cu101
#     Uninstalling torchvision-0.9.0+cu101:
#       Successfully uninstalled torchvision-0.9.0+cu101
# Successfully installed torch-1.7.1+cu110 torchaudio-0.7.2 torchvision-0.8.2+cu110

# %%
# !pip install efficientnet_pytorch tez
# Out:
# Collecting efficientnet_pytorch
#   Downloading https://files.pythonhosted.org/packages/4e/83/f9c5f44060f996279e474185ebcbd8dbd91179593bffb9abe3afa55d085b/efficientnet_pytorch-0.7.0.tar.gz
# Collecting tez
#   Downloading https://files.pythonhosted.org/packages/56/37/9b99ae05da3fa2b05a4cbb0cf78c50dfdcf805b55f29029c3cb6c5a0fee1/tez-0.1.2-py3-none-any.whl
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from efficientnet_pytorch) (1.7.1+cu110)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet_pytorch) (1.19.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet_pytorch) (3.7.4.3)
# Building wheels for collected packages: efficientnet-pytorch
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.0-cp37-none-any.whl size=16031 sha256=e5046f7307482bdf2f30d9ef4fa10c29789caaa429926cee2ed7d97cfd2195f8
#   Stored in directory: /root/.cache/pip/wheels/e9/c6/e1/7a808b26406239712cfce4b5ceeb67d9513ae32aa4b31445c6
# Successfully built efficientnet-pytorch
# Installing collected packages: efficientnet-pytorch, tez
# Successfully installed efficientnet-pytorch-0.7.0 tez-0.1.2

# %%
# os.getcwd()
import os
path = "/content/drive/MyDrive/sgmoid_education/computer vision 2D/ophthalmology/"
os.chdir(path)

# %%
from sgmoid_education import *

# %%
ophthalmology_data = np.load(path + 'retinamnist.npz')
lst = ophthalmology_data.files
print(lst)
# for item in lst:
#     print(item)
#     print(data[item])
# Out:
# ['train_images', 'val_images', 'test_images', 'train_labels', 'val_labels', 'test_labels']

# %%
print(f"Train data size: {ophthalmology_data['train_images'].shape[0]}")
print(f"Validation data size: {ophthalmology_data['val_images'].shape[0]}")
print(f"Test data size: {ophthalmology_data['test_images'].shape[0]}")
print(f"Input image size: {ophthalmology_data['train_images'].shape[1:]}")
# Out:
# Train data size: 1080
# Validation data size: 120
# Test data size: 400
# Input image size: (28, 28, 3)

# %%
train_dataset = ImageDataset(images=ophthalmology_data['train_images'], 
                             targets=ophthalmology_data['train_labels'].reshape(-1))

val_dataset = ImageDataset(images=ophthalmology_data['val_images'], 
                           targets=ophthalmology_data['val_labels'].reshape(-1))

test_dataset = ImageDataset(images=ophthalmology_data['test_images'], 
                            targets=ophthalmology_data['test_labels'].reshape(-1))

# %%
classes=len(set(ophthalmology_data['val_labels'].reshape(-1)))
classes
# Out:
# 5

# %% [markdown]
# ## Visualize Batch

# %%
show_batch(DataLoader(train_dataset, batch_size=64, shuffle=True))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
model = ImageClassifier(num_classes=classes)
# Out:
# Loaded pretrained weights for efficientnet-b0

# %% [markdown]
# tez = a wrapper that provides the training loop & model callbacks efficiently

# %%
es = tez.callbacks.EarlyStopping(monitor="valid_accuracy", 
                                 model_path=path + "model.bin", 
                                 patience=5, 
                                 mode="max")

model.fit(train_dataset=train_dataset, valid_dataset=val_dataset,
    train_bs = 32,
    valid_bs = 32,
    callbacks=[es],
    fp16=True,
    epochs=30,
    device="cuda"
)
# Out:
# 100%|██████████| 34/34 [00:03<00:00, 10.45it/s, accuracy=0.409, loss=1.45, stage=train]
# 100%|██████████| 4/4 [00:00<00:00,  5.02it/s, accuracy=0.169, loss=1.6, stage=valid]
#   0%|          | 0/34 [00:00<?, ?it/s]
# Validation score improved (-inf --> 0.16927083333333334). Saving model!
# 100%|██████████| 34/34 [00:03<00:00, 10.34it/s, accuracy=0.464, loss=1.32, stage=train]
# 100%|██████████| 4/4 [00:00<00:00,  5.00it/s, accuracy=0.169, loss=1.66, stage=valid]
#   0%|          | 0/34 [00:00<?, ?it/s]
# EarlyStopping counter: 1 out of 5
# 100%|██████████| 34/34 [00:03<00:00, 10.53it/s, accuracy=0.499, loss=1.27, stage=train]
# 100%|██████████| 4/4 [00:00<00:00,  5.07it/s, accuracy=0.177, loss=1.67, stage=valid]
#   0%|          | 0/34 [00:00<?, ?it/s]
# Validation score improved (0.16927083333333334 --> 0.17708333333333334). Saving model!
# 100%|██████████| 34/34 [00:03<00:00, 10.55it/s, accuracy=0.508, loss=1.23, stage=train]
# 100%|██████████| 4/4 [00:00<00:00,  5.00it/s, accuracy=0.161, loss=1.67, stage=valid]
#   0%|          | 0/34 [00:00<?, ?it/s]
# EarlyStopping counter: 1 out of 5
# 100%|██████████| 34/34 [00:03<00:00, 10.50it/s, accuracy=0.502, loss=1.23, stage=train]
# 100%|██████████| 4/4 [00:00<00:00,  5.18it/s, accuracy=0.18, loss=1.62, stage=valid]
#   0%|          | 0/34 [00:00<?, ?it/s]
# Validation score improved (0.17708333333333334 --> 0.1796875). Saving model!
# 100%|██████████| 34/34 [00:03<00:00, 10.50it/s, accuracy=0.524, loss=1.2, stage=train]
# 100%|██████████| 4/4 [00:00<00:00,  4.88it/s, accuracy=0.26, loss=1.55, stage=valid]
#   0%|          | 0/34 [00:00<?, ?it/s]
# Validation score improved (0.1796875 --> 0.2604166666666667). Saving model!
# 100%|██████████| 34/34 [00:03<00:00, 10.52it/s, accuracy=0.518, loss=1.2, stage=train]
# 100%|██████████| 4/4 [00:00<00:00,  5.09it/s, accuracy=0.315, loss=1.51, stage=valid]
#   0%|          | 0/34 [00:00<?, ?it/s]
# Validation score improved (0.2604166666666667 --> 0.3151041666666667). Saving model!
# 100%|██████████| 34/34 [00:03<00:00, 10.53it/s, accuracy=0.527, loss=1.19, stage=train]
# 100%|██████████| 4/4 [00:00<00:00,  5.05it/s, accuracy=0.362, loss=1.47, stage=valid]
#   0%|          | 0/34 [00:00<?, ?it/s]
# Validation score improved (0.3151041666666667 --> 0.3619791666666667). Saving model!
# 100%|██████████| 34/34 [00:03<00:00, 10.49it/s, accuracy=0.523, loss=1.2, stage=train]
# 100%|██████████| 4/4 [00:00<00:00,  5.10it/s, accuracy=0.378, loss=1.43, stage=valid]
#   0%|          | 0/34 [00:00<?, ?it/s]
# Validation score improved (0.3619791666666667 --> 0.3776041666666667). Saving model!
# 100%|██████████| 34/34 [00:03<00:00, 10.37it/s, accuracy=0.524, loss=1.19, stage=train]
# 100%|██████████| 4/4 [00:00<00:00,  5.02it/s, accuracy=0.443, loss=1.38, stage=valid]
#   0%|          | 0/34 [00:00<?, ?it/s]
# Validation score improved (0.3776041666666667 --> 0.4427083333333333). Saving model!
# 100%|██████████| 34/34 [00:03<00:00, 10.54it/s, accuracy=0.524, loss=1.2, stage=train]
# 100%|██████████| 4/4 [00:00<00:00,  5.00it/s, accuracy=0.451, loss=1.31, stage=valid]
#   0%|          | 0/34 [00:00<?, ?it/s]
# Validation score improved (0.4427083333333333 --> 0.4505208333333333). Saving model!
# 100%|██████████| 34/34 [00:03<00:00, 10.60it/s, accuracy=0.525, loss=1.17, stage=train]
# 100%|██████████| 4/4 [00:00<00:00,  5.07it/s, accuracy=0.435, loss=1.27, stage=valid]
#   0%|          | 0/34 [00:00<?, ?it/s]
# EarlyStopping counter: 1 out of 5
# 100%|██████████| 34/34 [00:03<00:00, 10.56it/s, accuracy=0.549, loss=1.16, stage=train]
# 100%|██████████| 4/4 [00:00<00:00,  5.11it/s, accuracy=0.435, loss=1.24, stage=valid]
#   0%|          | 0/34 [00:00<?, ?it/s]
# EarlyStopping counter: 2 out of 5
# 100%|██████████| 34/34 [00:03<00:00, 10.33it/s, accuracy=0.558, loss=1.15, stage=train]
# 100%|██████████| 4/4 [00:00<00:00,  5.12it/s, accuracy=0.445, loss=1.21, stage=valid]
#   0%|          | 0/34 [00:00<?, ?it/s]
# EarlyStopping counter: 3 out of 5
# 100%|██████████| 34/34 [00:03<00:00, 10.26it/s, accuracy=0.54, loss=1.14, stage=train]
# 100%|██████████| 4/4 [00:00<00:00,  5.15it/s, accuracy=0.469, loss=1.18, stage=valid]
#   0%|          | 0/34 [00:00<?, ?it/s]
# Validation score improved (0.4505208333333333 --> 0.46875). Saving model!
# 100%|██████████| 34/34 [00:03<00:00, 10.38it/s, accuracy=0.551, loss=1.14, stage=train]
# 100%|██████████| 4/4 [00:00<00:00,  4.93it/s, accuracy=0.461, loss=1.17, stage=valid]
#   0%|          | 0/34 [00:00<?, ?it/s]
# EarlyStopping counter: 1 out of 5
# 100%|██████████| 34/34 [00:03<00:00, 10.62it/s, accuracy=0.565, loss=1.13, stage=train]
# 100%|██████████| 4/4 [00:00<00:00,  4.99it/s, accuracy=0.427, loss=1.15, stage=valid]
#   0%|          | 0/34 [00:00<?, ?it/s]
# EarlyStopping counter: 2 out of 5
# 100%|██████████| 34/34 [00:03<00:00, 10.30it/s, accuracy=0.561, loss=1.13, stage=train]
# 100%|██████████| 4/4 [00:00<00:00,  4.97it/s, accuracy=0.487, loss=1.14, stage=valid]
#   0%|          | 0/34 [00:00<?, ?it/s]
# Validation score improved (0.46875 --> 0.48697916666666663). Saving model!
# 100%|██████████| 34/34 [00:03<00:00, 10.51it/s, accuracy=0.558, loss=1.12, stage=train]
# 100%|██████████| 4/4 [00:00<00:00,  5.17it/s, accuracy=0.505, loss=1.13, stage=valid]
#   0%|          | 0/34 [00:00<?, ?it/s]
# Validation score improved (0.48697916666666663 --> 0.5052083333333334). Saving model!
# 100%|██████████| 34/34 [00:03<00:00, 10.54it/s, accuracy=0.557, loss=1.13, stage=train]
# 100%|██████████| 4/4 [00:00<00:00,  5.13it/s, accuracy=0.529, loss=1.13, stage=valid]
#   0%|          | 0/34 [00:00<?, ?it/s]
# Validation score improved (0.5052083333333334 --> 0.5286458333333334). Saving model!
# 100%|██████████| 34/34 [00:03<00:00, 10.60it/s, accuracy=0.556, loss=1.12, stage=train]
# 100%|██████████| 4/4 [00:00<00:00,  5.08it/s, accuracy=0.544, loss=1.12, stage=valid]
#   0%|          | 0/34 [00:00<?, ?it/s]
# Validation score improved (0.5286458333333334 --> 0.5442708333333334). Saving model!
# 100%|██████████| 34/34 [00:03<00:00, 10.47it/s, accuracy=0.559, loss=1.12, stage=train]
# 100%|██████████| 4/4 [00:00<00:00,  5.02it/s, accuracy=0.529, loss=1.12, stage=valid]
#   0%|          | 0/34 [00:00<?, ?it/s]
# EarlyStopping counter: 1 out of 5
# 100%|██████████| 34/34 [00:03<00:00, 10.30it/s, accuracy=0.583, loss=1.11, stage=train]
# 100%|██████████| 4/4 [00:00<00:00,  5.00it/s, accuracy=0.555, loss=1.12, stage=valid]
#   0%|          | 0/34 [00:00<?, ?it/s]
# Validation score improved (0.5442708333333334 --> 0.5546875). Saving model!
# 100%|██████████| 34/34 [00:03<00:00, 10.48it/s, accuracy=0.579, loss=1.1, stage=train]
# 100%|██████████| 4/4 [00:00<00:00,  4.95it/s, accuracy=0.562, loss=1.11, stage=valid]
#   0%|          | 0/34 [00:00<?, ?it/s]
# Validation score improved (0.5546875 --> 0.5625). Saving model!
# 100%|██████████| 34/34 [00:03<00:00, 10.51it/s, accuracy=0.589, loss=1.1, stage=train]
# 100%|██████████| 4/4 [00:00<00:00,  5.03it/s, accuracy=0.562, loss=1.11, stage=valid]
#   0%|          | 0/34 [00:00<?, ?it/s]
# EarlyStopping counter: 1 out of 5
# 100%|██████████| 34/34 [00:03<00:00, 10.25it/s, accuracy=0.583, loss=1.09, stage=train]
# 100%|██████████| 4/4 [00:00<00:00,  5.00it/s, accuracy=0.57, loss=1.11, stage=valid]
#   0%|          | 0/34 [00:00<?, ?it/s]
# Validation score improved (0.5625 --> 0.5703125). Saving model!
# 100%|██████████| 34/34 [00:03<00:00, 10.46it/s, accuracy=0.59, loss=1.08, stage=train]
# 100%|██████████| 4/4 [00:00<00:00,  4.97it/s, accuracy=0.578, loss=1.11, stage=valid]
#   0%|          | 0/34 [00:00<?, ?it/s]
# Validation score improved (0.5703125 --> 0.578125). Saving model!
# 100%|██████████| 34/34 [00:03<00:00, 10.45it/s, accuracy=0.574, loss=1.08, stage=train]
# 100%|██████████| 4/4 [00:00<00:00,  5.11it/s, accuracy=0.562, loss=1.11, stage=valid]
#   0%|          | 0/34 [00:00<?, ?it/s]
# EarlyStopping counter: 1 out of 5
# 100%|██████████| 34/34 [00:03<00:00, 10.26it/s, accuracy=0.582, loss=1.08, stage=train]
# 100%|██████████| 4/4 [00:00<00:00,  4.85it/s, accuracy=0.56, loss=1.11, stage=valid]
#   0%|          | 0/34 [00:00<?, ?it/s]
# EarlyStopping counter: 2 out of 5
# 100%|██████████| 34/34 [00:03<00:00, 10.50it/s, accuracy=0.59, loss=1.09, stage=train]
# 100%|██████████| 4/4 [00:00<00:00,  5.00it/s, accuracy=0.578, loss=1.11, stage=valid]
# EarlyStopping counter: 3 out of 5

# %% [markdown]
# # Performance Metric

# %%
prediction(model, train_dataset, "train")
prediction(model, val_dataset, "val")
prediction(model, test_dataset, "test")
# Out:
# Accuracy on train: 62.69%
# Accuracy on val: 55.00%
# Accuracy on test: 54.50%

# %%
plot_confusion_matrix(model, test_dataset, labels=['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc'])

# %%
date = pd.to_datetime("27th of January, 1756")

# %%
date
# Out:
# Timestamp('1756-01-27 00:00:00')
